# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()

# %%
client = genai.Client(api_key=os.environ.get("GEMINI_API_KEY"))

# %% [markdown]
# # 1. Simple Text Completion
# Goal: Create a Python script that sends a prompt to Gemini and prints the generated response.
# Example Task: Prompt → 'Explain black holes like I’m 10 years old.'
# Focus:
# - API setup
# - Handling responses

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain black holes like I’m 10 years old",
)
print(response.text)
# Out:
# Okay, imagine you have a superhero with super-duper strong muscles, right?
#
# Well, a **black hole** is like a super-duper strong *object* in space. It's not actually a hole, like a pit you can fall into. It's more like a really, really, *really* squished ball of stuff.
#
# Here's why it's so special:
#
# 1.  **Super Strong Gravity:** You know how the Earth has gravity that pulls you down and keeps you from floating away? A black hole has gravity that is a *million billion* times stronger! It's like having a giant invisible magnet that pulls everything toward it.
#
# 2.  **It Eats Light!** Because its gravity is so incredibly strong, it pulls everything nearby, even *light*! Light is the fastest thing in the whole universe, but even light can't escape a black hole once it gets too close. That's why we call them "black"—because no light can get out of them, so you can't see them directly. It's like a room that's so dark, no light bulb could ever make it bright.
#
# ...

# %% [markdown]
# # 2. Chat Memory Simulation
# Goal: Build a chat loop that keeps conversation history in a list and sends it as context to Gemini.
# Focus:
# - Maintain session memory
# - Manage role-based conversation structure (user, model)

# %%
while True:
    q = input("\nAsk something (or type 'exit'): ")
    if q.lower() == 'exit':
        break
    top_chunks = retrieve(q, model, index, sentences)
    context = "\n".join(top_chunks)
    print("\nRetrieved Context:\n", context)
    answer = ask_gemini(context, q)
    print("\nGemini Answer:\n", answer)
